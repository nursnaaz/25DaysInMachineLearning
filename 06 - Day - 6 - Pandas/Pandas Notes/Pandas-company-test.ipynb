# %%
import pandas as pd

# %%
df = pd.read_csv("companytest.csv")

# %%
df.head()
# Out:
#   Company   Age  Salary
# 0     'a'  20.0     NaN
# 1       c  30.0     NaN
# 2     'a'  35.0  2300.0
# 3       c  40.0  3000.0
# 4       a  23.0  4000.0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Company    27 non-null object
# Age        26 non-null float64
# Salary     23 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 800.0+ bytes

# %%
df.describe()
# Out:
#              Age       Salary
# count  26.000000    23.000000
# mean   31.230769  4923.086957
# std     9.240380  2607.600271
# min    18.000000  1089.000000
# 25%    23.000000  3000.000000
# 50%    33.000000  4824.000000
# 75%    36.500000  7042.000000
# max    50.000000  9284.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.columns = ['Organization','Age','Compensation']

# %%
df
# Out:
#    Organization   Age  Compensation
# 0           'a'  20.0           NaN
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# ...

# %%
df = df.rename(columns={'Age':'age'})

# %%
df
# Out:
#    Organization   age  Compensation
# 0           'a'  20.0           NaN
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# ...

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isna().sum()
# Out:
# Organization    3
# age             4
# Compensation    7
# dtype: int64

# %%
df.notna().sum()
# Out:
# Organization    27
# age             26
# Compensation    23
# dtype: int64

# %%
df.drop("age", axis="columns")
# Out:
#    Organization  Compensation
# 0           'a'           NaN
# 1             c           NaN
# 2           'a'        2300.0
# 3             c        3000.0
# 4             a        4000.0
# 5             c        5000.0
# 6             a        6000.0
# 7           'c'        7000.0
# 8             a        8000.0
# 9             b        9000.0
# 10            b           NaN
# 11            b        1089.0
# 12            b           NaN
# 13            b        1234.0
# 14          NaN        3000.0
# 15            a        3000.0
# 16            c        3030.0
# 17            a        5000.0
# 18          NaN           NaN
# 19            c           NaN
# 20            a        3045.0
# 21            c        3184.0
# 22            a        4824.0
# 23            c        5835.0
# 24          NaN        7084.0
# 25            c        8943.0
# 26            a        8345.0
# 27            b        9284.0
# 28            b           NaN
# 29            b        2034.0

# %%
df.drop([10,3],axis="index")
# Out:
#    Organization   age  Compensation
# 0           'a'  20.0           NaN
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# 25            c  23.0        8943.0
# 26            a  34.0        8345.0
# ...

# %%
df.iloc[2,1]
# Out:
# 35.0

# %%
df.iloc[2,1] = 38.0

# %%
df.loc[2,"age"]=35.0

# %%
df.loc[2,"age"]
# Out:
# 35.0

# %%
df.iloc[2,1]
# Out:
# 38.0

# %%
df.iloc[1:,2:]
# Out:
#     Compensation
# 1            NaN
# 2         2300.0
# 3         3000.0
# 4         4000.0
# 5         5000.0
# 6         6000.0
# 7         7000.0
# 8         8000.0
# 9         9000.0
# 10           NaN
# 11        1089.0
# 12           NaN
# 13        1234.0
# 14        3000.0
# 15        3000.0
# 16        3030.0
# 17        5000.0
# 18           NaN
# 19           NaN
# 20        3045.0
# 21        3184.0
# 22        4824.0
# 23        5835.0
# 24        7084.0
# 25        8943.0
# 26        8345.0
# 27        9284.0
# 28           NaN
# 29        2034.0

# %%
df.loc[1:,"age":]
# Out:
#      age  Compensation
# 1   30.0           NaN
# 2   38.0        2300.0
# 3   40.0        3000.0
# 4   23.0        4000.0
# 5    NaN        5000.0
# 6    NaN        6000.0
# 7   23.0        7000.0
# 8   34.0        8000.0
# 9   45.0        9000.0
# 10  23.0           NaN
# 11  34.0        1089.0
# 12  45.0           NaN
# 13  18.0        1234.0
# 14  40.0        3000.0
# 15  23.0        3000.0
# 16  23.0        3030.0
# 17  34.0        5000.0
# 18  22.0           NaN
# 19  32.0           NaN
# 20  37.0        3045.0
# 21  50.0        3184.0
# 22  21.0        4824.0
# 23   NaN        5835.0
# 24   NaN        7084.0
# 25  23.0        8943.0
# 26  34.0        8345.0
# 27  45.0        9284.0
# 28  23.0           NaN
# 29  35.0        2034.0

# %%
df["Organization"].unique()
# Out:
# array(["'a'", 'c', 'a', "'c'", 'b', nan], dtype=object)

# %%
df["Organization"] = df.Organization.replace({"'a'":'a',"'c'":"c"})

# %%
df["Organization"].unique()
# Out:
# array(['a', 'c', 'b', nan], dtype=object)

# %%
df.Organization.isna().sum()
# Out:
# 3

# %%
df.dropna(subset=["Organization"])
# Out:
#    Organization   age  Compensation
# 0             a  20.0           NaN
# 1             c  30.0           NaN
# 2             a  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7             c  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 25            c  23.0        8943.0
# 26            a  34.0        8345.0
# 27            b  45.0        9284.0
# ...

# %%
df["Organization"].mode()[0]
# Out:
# 'a'

# %%
df["Organization"] = df.Organization.fillna(df["Organization"].mode()[0])

# %%
df.isna().sum()
# Out:
# Organization    0
# age             4
# Compensation    7
# dtype: int64

# %%
df
# Out:
#    Organization   age  Compensation
# 0             a  20.0           NaN
# 1             c  30.0           NaN
# 2             a  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7             c  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14            a  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18            a  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24            a   NaN        7084.0
# ...

# %%
df.age.describe()
# Out:
# count    26.000000
# mean     31.230769
# std       9.240380
# min      18.000000
# 25%      23.000000
# 50%      33.000000
# 75%      36.500000
# max      50.000000
# Name: age, dtype: float64

# %%
df.dropna(subset=["age"])
# Out:
#    Organization   age  Compensation
# 0             a  20.0           NaN
# 1             c  30.0           NaN
# 2             a  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 7             c  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14            a  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18            a  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 25            c  23.0        8943.0
# 26            a  34.0        8345.0
# 27            b  45.0        9284.0
# 28            b  23.0           NaN
# ...

# %%
df["age"] = df.age.fillna(df.age.mean())

# %%
df.isna().sum()
# Out:
# Organization    0
# age             0
# Compensation    7
# dtype: int64

# %%
df["Compensation"] = df.Compensation.fillna(df.Compensation.median())

# %%
df.isna().sum()
# Out:
# Organization    0
# age             0
# Compensation    0
# dtype: int64

# %%
df.Organization.value_counts()
# Out:
# a    13
# c     9
# b     8
# Name: Organization, dtype: int64

# %%
df
# Out:
#    Organization        age  Compensation
# 0             a  20.000000        4824.0
# 1             c  30.000000        4824.0
# 2             a  35.000000        2300.0
# 3             c  40.000000        3000.0
# 4             a  23.000000        4000.0
# 5             c  31.230769        5000.0
# 6             a  31.230769        6000.0
# 7             c  23.000000        7000.0
# 8             a  34.000000        8000.0
# 9             b  45.000000        9000.0
# 10            b  23.000000        4824.0
# 11            b  34.000000        1089.0
# 12            b  45.000000        4824.0
# 13            b  18.000000        1234.0
# 14            a  40.000000        3000.0
# 15            a  23.000000        3000.0
# 16            c  23.000000        3030.0
# 17            a  34.000000        5000.0
# 18            a  22.000000        4824.0
# 19            c  32.000000        4824.0
# 20            a  37.000000        3045.0
# 21            c  50.000000        3184.0
# ...

# %%
df[df.duplicated()]
# Out:
#    Organization   age  Compensation
# 28            b  23.0        4824.0

# %%
df[(df["Organization"]=='b') & (df['age']==23.0)]
# Out:
#    Organization   age  Compensation
# 10            b  23.0        4824.0
# 28            b  23.0        4824.0

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Organization, age, Compensation]
# Index: []

# %%
df.groupby("Organization").age.mean()
# Out:
# Organization
# a    29.650888
# b    35.000000
# c    31.495726
# Name: age, dtype: float64

# %%
df.groupby(["Organization","age"]).Compensation.mean()
# Out:
# Organization  age
# a             20.000000    4824.000000
#               21.000000    4824.000000
#               22.000000    4824.000000
#               23.000000    3500.000000
#               31.230769    6542.000000
#               34.000000    7115.000000
#               35.000000    2300.000000
#               37.000000    3045.000000
#               40.000000    3000.000000
# b             18.000000    1234.000000
#               23.000000    4824.000000
#               34.000000    1089.000000
#               35.000000    2034.000000
#               45.000000    7702.666667
# c             23.000000    6324.333333
#               30.000000    4824.000000
#               31.230769    5417.500000
#               32.000000    4824.000000
#               40.000000    3000.000000
#               50.000000    3184.000000
# Name: Compensation, dtype: float64

# %%
df.groupby("Organization").age.agg(["mean","median"])
# Out:
#                    mean     median
# Organization
# a             29.650888  31.230769
# b             35.000000  35.000000
# c             31.495726  31.230769

# %%
# %matplotlib inline

# %%
df["age"].plot(kind="hist")

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df["age"],y = df["Compensation"])
plt.show()

# %%
df.Compensation.value_counts()
# Out:
# 4824.0    7
# 3000.0    3
# 5000.0    2
# 8345.0    1
# 2300.0    1
# 4000.0    1
# 6000.0    1
# 7000.0    1
# 8000.0    1
# 9000.0    1
# 8943.0    1
# 1234.0    1
# 3030.0    1
# 3045.0    1
# 3184.0    1
# 7084.0    1
# 9284.0    1
# 2034.0    1
# 5835.0    1
# 1089.0    1
# Name: Compensation, dtype: int64

# %%
df.Organization.value_counts().plot(kind='pie')

# %%
df.query('age == 23.0 & Organization =="b"')
# Out:
#    Organization   age  Compensation
# 10            b  23.0        4824.0

# %%
df[(df["Organization"]=='b') & (df['age']==23.0)]
# Out:
#    Organization   age  Compensation
# 10            b  23.0        4824.0
